# %% [markdown]
# ## <center> Decision Tree Regression (No capped dataset)
# #### <center> By: $\color{red}{\text{Amirehsan Ghasemi}}$

# %% [markdown]
# ### Importing Modules

# %%
#....> Importing the base libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import time


#....> AI/ML modules
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

#from sklearn import linear_model
from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score  
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score



#....> Preventing warnings
import warnings      #....> Prevent from printing the warning of plotting
warnings.simplefilter(action="ignore", category=FutureWarning)

#....................................................................................................
#....................................................................................................
print('Modules are imported')  #....> If prints, this means that the modules are imported correctly
# Out:
# Modules are imported

# %% [markdown]
# ### Read in all our data

# %%
df = pd.read_csv('housing.csv')  #....> Importing dataframe
rows,columns = df.shape
print("Dataframe number of rows: ", rows)
print("Dataframe number of columns: ", columns)
# Out:
# Dataframe number of rows:  20640
# Dataframe number of columns:  10

# %% [markdown]
# ### Checking the data structure

# %%
df.head(n=5)     # Show the first 5 rows (each row: one district)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
#....> Remove capped values of prices USD 500000
df=df[df['median_house_value'] < 490000]
df.head(n=5)  #....> Show the first 5 rows (each row: one district)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# #### Notice: All features are numerical, except the $\color{red}{\text{ocean_proximity}}$. Its type is object and its text feature (Categorical feature)

# %% [markdown]
# #### It might be interesting to add the possibly helpful attributes combinations and study their effect on modeling. So:

# %%
df["rooms_per_household"]      = df["total_rooms"]/df["households"]
df["bedrooms_per_room"]        = df["total_bedrooms"]/df["total_rooms"]
df["population_per_household"] = df["population"]/df["households"]

df.head(n=5)    #....> Show the first 5 rows
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity  \
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY
#
#    rooms_per_household  bedrooms_per_room  population_per_household
# 0             6.984127           0.146591                  2.555556
# 1             6.238137           0.155797                  2.109842
# 2             8.288136           0.129516                  2.802260
# 3             5.817352           0.184458                  2.547945
# 4             6.281853           0.172096                  2.181467

# %% [markdown]
# ### Handling categorical feature (ocean_proximity)

# %% [markdown]
# #### First, we have to explore this categorical feature

# %%
df["ocean_proximity"].value_counts()    #....> Return a Series containing counts of unique values
# Out:
# <1H OCEAN     8571
# INLAND        6523
# NEAR OCEAN    2428
# NEAR BAY      2081
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# #### Asssigning numerical values to ocean proximity in the gradient order: the lower the number the further away is the house from the ocean. This gradient is chosen for the better and easier interpretation of models results (feature importances)

# %%
df.loc[df['ocean_proximity'] == 'NEAR OCEAN', 'ocean_proximity'] = 4
df.loc[df['ocean_proximity'] == 'NEAR BAY', 'ocean_proximity']   = 3
df.loc[df['ocean_proximity'] == '<1H OCEAN', 'ocean_proximity']  = 2
df.loc[df['ocean_proximity'] == 'INLAND', 'ocean_proximity']     = 1
df.loc[df['ocean_proximity'] == 'ISLAND', 'ocean_proximity']     = 0

df     #....> Show the dataframe
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  rooms_per_household  bedrooms_per_room  \
# 0                   3             6.984127           0.146591
# 1                   3             6.238137           0.155797
# 2                   3             8.288136           0.129516
# 3                   3             5.817352           0.184458
# 4                   3             6.281853           0.172096
# ...               ...                  ...                ...
# 20635               1             5.045455           0.224625
# 20636               1             6.114035           0.215208
# 20637               1             5.205543           0.215173
# 20638               1             5.329513           0.219892
# 20639               1             5.254717           0.221185
#
#        population_per_household
# 0                      2.555556
# 1                      2.109842
# 2                      2.802260
# 3                      2.547945
# 4                      2.181467
# ...                         ...
# 20635                  2.560606
# 20636                  3.122807
# 20637                  2.325635
# 20638                  2.123209
# 20639                  2.616981
#
# [19608 rows x 13 columns]

# %% [markdown]
# ### Splitting the dataset
#
# #### Now the data will be splitted in train and test set to avoid the data leakage and bias during the further preprocessing steps, which include cleaning the missing values and feature scaling.

# %%
train_set1, test_set1 = train_test_split(df, test_size=0.2, random_state=1)
print("Training Data:", len(train_set1))
print("Testing Data:", len(test_set1))
# Out:
# Training Data: 15686
# Testing Data: 3922

# %% [markdown]
# ### Data cleaning (Training set and Testing set)
#
# #### Check if there are any missing values (NaN or None)

# %%
#....> For Training set
missing_values_count = train_set1.isnull().sum()
missing_values_count[:]
# Out:
# longitude                     0
# latitude                      0
# housing_median_age            0
# total_rooms                   0
# total_bedrooms              146
# population                    0
# households                    0
# median_income                 0
# median_house_value            0
# ocean_proximity               0
# rooms_per_household           0
# bedrooms_per_room           146
# population_per_household      0
# dtype: int64

# %%
#....> For Testing set
missing_values_count = test_set1.isnull().sum()
missing_values_count[:]
# Out:
# longitude                    0
# latitude                     0
# housing_median_age           0
# total_rooms                  0
# total_bedrooms              54
# population                   0
# households                   0
# median_income                0
# median_house_value           0
# ocean_proximity              0
# rooms_per_household          0
# bedrooms_per_room           54
# population_per_household     0
# dtype: int64

# %% [markdown]
# ### It's helpful to see what percentage of the values in our dataset were missing. It gives us a better sense of the scale of this problem

# %%
#....> Defining a function to find the percentage of the values in our dataset were missing
def finding_percentage(df):
    total_cells     = np.product(df.shape)
    total_missing   = missing_values_count.sum()
    percent_missing = (total_missing/total_cells)*100
    return percent_missing

# %%
#....> Calling the finding_percange functtion
print('Percent of data that is missing in Training set:', finding_percentage(train_set1))
print('Percent of data that is missing in Testing set:', finding_percentage(test_set1))
# Out:
# Percent of data that is missing in Training set: 0.052962465304681294
# Percent of data that is missing in Testing set: 0.21182285333228731

# %% [markdown]
# ### Replacing NAN with Imputer (median) using Scikit-learn

# %%
#....> Training Set
imputer = SimpleImputer(strategy = "median") #....> Using medain
housing_numerical_attributes = train_set1.drop("ocean_proximity", axis = 1)
imputer.fit(housing_numerical_attributes)  
X1 = imputer.transform(housing_numerical_attributes)

# %%
#....> Testing Set
imputer = SimpleImputer(strategy = "median")  #....> Using medain
housing_numerical_attributes1 = test_set1.drop("ocean_proximity", axis = 1)
imputer.fit(housing_numerical_attributes)  
X2 = imputer.transform(housing_numerical_attributes1)

# %% [markdown]
# #### For Both Training and Testing sets the NAN values are replaced with medain
# #### Put back the ocean proximity in train and test sets:

# %%
#....> Training Set
train_set = pd.DataFrame(X1, columns = housing_numerical_attributes.columns, index = housing_numerical_attributes.index)
train_set.insert(9,"ocean_proximity",df["ocean_proximity"],True)
train_set    #....> Show the Training set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2736     -115.57     32.79                50.0       1291.0           277.0
# 17659    -121.88     37.28                33.0       2951.0           529.0
# 17654    -121.89     37.25                21.0       2080.0           352.0
# 17544    -121.87     37.34                52.0       1170.0           215.0
# 8772     -118.34     33.80                33.0       2194.0           469.0
# ...          ...       ...                 ...          ...             ...
# 11575    -118.00     33.77                28.0       2401.0           503.0
# 18228    -122.09     37.41                18.0       1476.0           473.0
# 5425     -118.42     34.02                34.0       2243.0           444.0
# 12799    -121.45     38.61                32.0       2436.0           612.0
# 236      -122.20     37.79                49.0        882.0           195.0
#
#        population  households  median_income  median_house_value  \
# 2736        864.0       274.0         1.6667             68100.0
# 17659      1288.0       521.0         4.1554            313100.0
# 17654      1040.0       325.0         5.2887            264500.0
# 17544       604.0       207.0         2.6667            325900.0
# 8772        987.0       397.0         5.0951            318900.0
# ...           ...         ...            ...                 ...
# 11575      1155.0       456.0         3.5139            211700.0
# 18228       838.0       415.0         3.5750            274000.0
# 5425        973.0       413.0         4.9676            414100.0
# 12799      1509.0       618.0         1.0424             81400.0
# 236         737.0       210.0         2.6667            122000.0
#
#       ocean_proximity  rooms_per_household  bedrooms_per_room  \
# 2736                1             4.711679           0.214562
# 17659               2             5.664107           0.179261
# 17654               2             6.400000           0.169231
# 17544               2             5.652174           0.183761
# 8772                2             5.526448           0.213765
# ...               ...                  ...                ...
# 11575               2             5.265351           0.209496
# 18228               3             3.556627           0.320461
# 5425                2             5.430993           0.197949
# 12799               1             3.941748           0.251232
# 236                 3             4.200000           0.221088
#
#        population_per_household
# 2736                   3.153285
# 17659                  2.472169
# 17654                  3.200000
# 17544                  2.917874
# 8772                   2.486146
# ...                         ...
# 11575                  2.532895
# 18228                  2.019277
# 5425                   2.355932
# 12799                  2.441748
# 236                    3.509524
#
# [15686 rows x 13 columns]

# %%
#....> Testing Set
test_set = pd.DataFrame(X2, columns = housing_numerical_attributes1.columns, index = housing_numerical_attributes1.index)

test_set.insert(9,"ocean_proximity",df["ocean_proximity"],True)
test_set  #....> Show the Testing set
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11212    -117.91     33.82                29.0       1444.0           326.0
# 10317    -117.82     33.84                25.0       1788.0           203.0
# 5086     -118.28     33.98                47.0        865.0           193.0
# 7988     -118.18     33.85                38.0       3596.0           862.0
# 14480    -117.25     32.82                19.0       5255.0           762.0
# ...          ...       ...                 ...          ...             ...
# 385      -122.29     37.90                49.0       1283.0           238.0
# 11924    -117.39     33.95                35.0       1599.0           284.0
# 13047    -121.28     38.55                35.0       7088.0          1279.0
# 10331    -117.77     33.84                 5.0       4380.0           715.0
# 14428    -117.25     32.80                31.0       2182.0           630.0
#
#        population  households  median_income  median_house_value  \
# 11212      1038.0       271.0         2.3843            182900.0
# 10317       676.0       217.0        10.1299            454300.0
# 5086        782.0       217.0         2.2411             93000.0
# 7988       2416.0       832.0         3.6897            169800.0
# 14480      1773.0       725.0         7.8013            474000.0
# ...           ...         ...            ...                 ...
# 385         576.0       236.0         3.3333            276800.0
# 11924       721.0       287.0         4.1250            120700.0
# 13047      4885.0      1272.0         2.6981            112500.0
# 10331      1913.0       741.0         6.7274            266400.0
# 14428      1069.0       599.0         2.9781            212500.0
#
#       ocean_proximity  rooms_per_household  bedrooms_per_room  \
# 11212               2             5.328413           0.225762
# 10317               2             8.239631           0.113535
# 5086                2             3.986175           0.223121
# 7988                2             4.322115           0.239711
# 14480               4             7.248276           0.145005
# ...               ...                  ...                ...
# 385                 3             5.436441           0.185503
# 11924               1             5.571429           0.177611
# 13047               1             5.572327           0.180446
# 10331               2             5.910931           0.163242
# 14428               4             3.642738           0.288726
#
#        population_per_household
# 11212                  3.830258
# 10317                  3.115207
# 5086                   3.603687
# 7988                   2.903846
# 14480                  2.445517
# ...                         ...
# 385                    2.440678
# 11924                  2.512195
# 13047                  3.840409
# 10331                  2.581646
# 14428                  1.784641
#
# [3922 rows x 13 columns]

# %% [markdown]
# ### Feature Scaling (Standardization)

# %%
train_set_without_target = train_set.drop("median_house_value", axis=1) #....> drop labels for training set 
train_set_without_target
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2736     -115.57     32.79                50.0       1291.0           277.0
# 17659    -121.88     37.28                33.0       2951.0           529.0
# 17654    -121.89     37.25                21.0       2080.0           352.0
# 17544    -121.87     37.34                52.0       1170.0           215.0
# 8772     -118.34     33.80                33.0       2194.0           469.0
# ...          ...       ...                 ...          ...             ...
# 11575    -118.00     33.77                28.0       2401.0           503.0
# 18228    -122.09     37.41                18.0       1476.0           473.0
# 5425     -118.42     34.02                34.0       2243.0           444.0
# 12799    -121.45     38.61                32.0       2436.0           612.0
# 236      -122.20     37.79                49.0        882.0           195.0
#
#        population  households  median_income ocean_proximity  \
# 2736        864.0       274.0         1.6667               1
# 17659      1288.0       521.0         4.1554               2
# 17654      1040.0       325.0         5.2887               2
# 17544       604.0       207.0         2.6667               2
# 8772        987.0       397.0         5.0951               2
# ...           ...         ...            ...             ...
# 11575      1155.0       456.0         3.5139               2
# 18228       838.0       415.0         3.5750               3
# 5425        973.0       413.0         4.9676               2
# 12799      1509.0       618.0         1.0424               1
# 236         737.0       210.0         2.6667               3
#
#        rooms_per_household  bedrooms_per_room  population_per_household
# 2736              4.711679           0.214562                  3.153285
# 17659             5.664107           0.179261                  2.472169
# 17654             6.400000           0.169231                  3.200000
# 17544             5.652174           0.183761                  2.917874
# 8772              5.526448           0.213765                  2.486146
# ...                    ...                ...                       ...
# 11575             5.265351           0.209496                  2.532895
# 18228             3.556627           0.320461                  2.019277
# 5425              5.430993           0.197949                  2.355932
# 12799             3.941748           0.251232                  2.441748
# 236               4.200000           0.221088                  3.509524
#
# [15686 rows x 12 columns]

# %%
test_set_without_target = test_set.drop("median_house_value", axis=1) #....> drop labels for testing set
test_set_without_target
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11212    -117.91     33.82                29.0       1444.0           326.0
# 10317    -117.82     33.84                25.0       1788.0           203.0
# 5086     -118.28     33.98                47.0        865.0           193.0
# 7988     -118.18     33.85                38.0       3596.0           862.0
# 14480    -117.25     32.82                19.0       5255.0           762.0
# ...          ...       ...                 ...          ...             ...
# 385      -122.29     37.90                49.0       1283.0           238.0
# 11924    -117.39     33.95                35.0       1599.0           284.0
# 13047    -121.28     38.55                35.0       7088.0          1279.0
# 10331    -117.77     33.84                 5.0       4380.0           715.0
# 14428    -117.25     32.80                31.0       2182.0           630.0
#
#        population  households  median_income ocean_proximity  \
# 11212      1038.0       271.0         2.3843               2
# 10317       676.0       217.0        10.1299               2
# 5086        782.0       217.0         2.2411               2
# 7988       2416.0       832.0         3.6897               2
# 14480      1773.0       725.0         7.8013               4
# ...           ...         ...            ...             ...
# 385         576.0       236.0         3.3333               3
# 11924       721.0       287.0         4.1250               1
# 13047      4885.0      1272.0         2.6981               1
# 10331      1913.0       741.0         6.7274               2
# 14428      1069.0       599.0         2.9781               4
#
#        rooms_per_household  bedrooms_per_room  population_per_household
# 11212             5.328413           0.225762                  3.830258
# 10317             8.239631           0.113535                  3.115207
# 5086              3.986175           0.223121                  3.603687
# 7988              4.322115           0.239711                  2.903846
# 14480             7.248276           0.145005                  2.445517
# ...                    ...                ...                       ...
# 385               5.436441           0.185503                  2.440678
# 11924             5.571429           0.177611                  2.512195
# 13047             5.572327           0.180446                  3.840409
# 10331             5.910931           0.163242                  2.581646
# 14428             3.642738           0.288726                  1.784641
#
# [3922 rows x 12 columns]

# %%
# Creating pandas series full of zeros to store the standard deviation and the mean from the training set.
std_dev_tr= pd.Series({col:0 for col in train_set_without_target.columns}, dtype="float32")
mean_tr= pd.Series({col:0 for col in train_set_without_target.columns}, dtype="float32")

# Getting the values for the mean and standard deviation from the training dataset.
for col in train_set_without_target.columns:
    std_dev_tr[col]= train_set_without_target[col].std()
    mean_tr[col]= train_set_without_target[col].mean()
    # Changing the training data so it is normalized with the mean and standard deviation from the training set.
    train_set_without_target[col]=(train_set_without_target[col]-mean_tr[col])/std_dev_tr[col]

for col in test_set_without_target.columns:
    # Changing the testing data so it is normalized with the mean and standard deviation from the training set.
    test_set_without_target[col]=(test_set_without_target[col]-mean_tr[col])/std_dev_tr[col]

# %%
train_set_without_target
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2736    1.987142 -1.326644            1.738389    -0.614893       -0.625995
# 17659  -1.162709  0.760676            0.376473     0.155700       -0.021575
# 17654  -1.167700  0.746729           -0.584880    -0.248629       -0.446108
# 17544  -1.157717  0.788569            1.898615    -0.671063       -0.774701
# 8772    0.604403 -0.857113            0.376473    -0.195709       -0.165485
# ...          ...       ...                 ...          ...             ...
# 11575   0.774125 -0.871060           -0.024091    -0.099617       -0.083936
# 18228  -1.267537  0.821111           -0.825218    -0.529014       -0.155891
# 5425    0.564468 -0.754839            0.456585    -0.172963       -0.225447
# 12799  -0.948059  1.378969            0.296360    -0.083370        0.177499
# 236    -1.322447  0.997766            1.658276    -0.804756       -0.822671
#
#        population  households  median_income ocean_proximity  \
# 2736    -0.516708   -0.595592      -1.281953       -1.054676
# 17659   -0.135922    0.053373       0.314878       -0.021924
# 17654   -0.358646   -0.461596       1.042040       -0.021924
# 17544   -0.750208   -0.771628      -0.640321       -0.021924
# 8772    -0.406244   -0.272424       0.917820       -0.021924
# ...           ...         ...            ...             ...
# 11575   -0.255367   -0.117408      -0.096730       -0.021924
# 18228   -0.540058   -0.225131      -0.057526        1.010828
# 5425    -0.418817   -0.230385       0.836012       -0.021924
# 12799    0.062553    0.308229      -1.682525       -1.054676
# 236     -0.630763   -0.763745      -0.640321        1.010828
#
#        rooms_per_household  bedrooms_per_room  population_per_household
# 2736             -0.299836          -0.005576                  0.003533
# 17659             0.141273          -0.627446                 -0.054483
# 17654             0.482095          -0.804145                  0.007512
# 17544             0.135746          -0.548183                 -0.016519
# 8772              0.077517          -0.019626                 -0.053292
# ...                    ...                ...                       ...
# 11575            -0.043408          -0.094825                 -0.049310
# 18228            -0.834789           1.859945                 -0.093059
# 5425              0.033308          -0.298237                 -0.064384
# 12799            -0.656423           0.640393                 -0.057074
# 236              -0.536816           0.109388                  0.033876
#
# [15686 rows x 12 columns]

# %%
train_set_without_target.insert(12,"median_house_value",train_set["median_house_value"]) #Put back the target values for train set
train_set_without_target
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2736    1.987142 -1.326644            1.738389    -0.614893       -0.625995
# 17659  -1.162709  0.760676            0.376473     0.155700       -0.021575
# 17654  -1.167700  0.746729           -0.584880    -0.248629       -0.446108
# 17544  -1.157717  0.788569            1.898615    -0.671063       -0.774701
# 8772    0.604403 -0.857113            0.376473    -0.195709       -0.165485
# ...          ...       ...                 ...          ...             ...
# 11575   0.774125 -0.871060           -0.024091    -0.099617       -0.083936
# 18228  -1.267537  0.821111           -0.825218    -0.529014       -0.155891
# 5425    0.564468 -0.754839            0.456585    -0.172963       -0.225447
# 12799  -0.948059  1.378969            0.296360    -0.083370        0.177499
# 236    -1.322447  0.997766            1.658276    -0.804756       -0.822671
#
#        population  households  median_income ocean_proximity  \
# 2736    -0.516708   -0.595592      -1.281953       -1.054676
# 17659   -0.135922    0.053373       0.314878       -0.021924
# 17654   -0.358646   -0.461596       1.042040       -0.021924
# 17544   -0.750208   -0.771628      -0.640321       -0.021924
# 8772    -0.406244   -0.272424       0.917820       -0.021924
# ...           ...         ...            ...             ...
# 11575   -0.255367   -0.117408      -0.096730       -0.021924
# 18228   -0.540058   -0.225131      -0.057526        1.010828
# 5425    -0.418817   -0.230385       0.836012       -0.021924
# 12799    0.062553    0.308229      -1.682525       -1.054676
# 236     -0.630763   -0.763745      -0.640321        1.010828
#
#        rooms_per_household  bedrooms_per_room  population_per_household  \
# 2736             -0.299836          -0.005576                  0.003533
# 17659             0.141273          -0.627446                 -0.054483
# 17654             0.482095          -0.804145                  0.007512
# 17544             0.135746          -0.548183                 -0.016519
# 8772              0.077517          -0.019626                 -0.053292
# ...                    ...                ...                       ...
# 11575            -0.043408          -0.094825                 -0.049310
# 18228            -0.834789           1.859945                 -0.093059
# 5425              0.033308          -0.298237                 -0.064384
# 12799            -0.656423           0.640393                 -0.057074
# 236              -0.536816           0.109388                  0.033876
#
#        median_house_value
# 2736              68100.0
# 17659            313100.0
# 17654            264500.0
# 17544            325900.0
# 8772             318900.0
# ...                   ...
# 11575            211700.0
# 18228            274000.0
# 5425             414100.0
# 12799             81400.0
# 236              122000.0
#
# [15686 rows x 13 columns]

# %%
train = train_set_without_target
train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2736    1.987142 -1.326644            1.738389    -0.614893       -0.625995
# 17659  -1.162709  0.760676            0.376473     0.155700       -0.021575
# 17654  -1.167700  0.746729           -0.584880    -0.248629       -0.446108
# 17544  -1.157717  0.788569            1.898615    -0.671063       -0.774701
# 8772    0.604403 -0.857113            0.376473    -0.195709       -0.165485
# ...          ...       ...                 ...          ...             ...
# 11575   0.774125 -0.871060           -0.024091    -0.099617       -0.083936
# 18228  -1.267537  0.821111           -0.825218    -0.529014       -0.155891
# 5425    0.564468 -0.754839            0.456585    -0.172963       -0.225447
# 12799  -0.948059  1.378969            0.296360    -0.083370        0.177499
# 236    -1.322447  0.997766            1.658276    -0.804756       -0.822671
#
#        population  households  median_income ocean_proximity  \
# 2736    -0.516708   -0.595592      -1.281953       -1.054676
# 17659   -0.135922    0.053373       0.314878       -0.021924
# 17654   -0.358646   -0.461596       1.042040       -0.021924
# 17544   -0.750208   -0.771628      -0.640321       -0.021924
# 8772    -0.406244   -0.272424       0.917820       -0.021924
# ...           ...         ...            ...             ...
# 11575   -0.255367   -0.117408      -0.096730       -0.021924
# 18228   -0.540058   -0.225131      -0.057526        1.010828
# 5425    -0.418817   -0.230385       0.836012       -0.021924
# 12799    0.062553    0.308229      -1.682525       -1.054676
# 236     -0.630763   -0.763745      -0.640321        1.010828
#
#        rooms_per_household  bedrooms_per_room  population_per_household  \
# 2736             -0.299836          -0.005576                  0.003533
# 17659             0.141273          -0.627446                 -0.054483
# 17654             0.482095          -0.804145                  0.007512
# 17544             0.135746          -0.548183                 -0.016519
# 8772              0.077517          -0.019626                 -0.053292
# ...                    ...                ...                       ...
# 11575            -0.043408          -0.094825                 -0.049310
# 18228            -0.834789           1.859945                 -0.093059
# 5425              0.033308          -0.298237                 -0.064384
# 12799            -0.656423           0.640393                 -0.057074
# 236              -0.536816           0.109388                  0.033876
#
#        median_house_value
# 2736              68100.0
# 17659            313100.0
# 17654            264500.0
# 17544            325900.0
# 8772             318900.0
# ...                   ...
# 11575            211700.0
# 18228            274000.0
# 5425             414100.0
# 12799             81400.0
# 236              122000.0
#
# [15686 rows x 13 columns]

# %%
test_set_without_target.insert(12,"median_house_value",test_set["median_house_value"]) #Put back the target values for test set
test_set_without_target
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11212   0.819052 -0.847816            0.056022    -0.543869       -0.508469
# 10317   0.863978 -0.838518           -0.264429    -0.384179       -0.803483
# 5086    0.634354 -0.773435            1.498051    -0.812648       -0.827468
# 7988    0.684272 -0.833869            0.777036     0.455117        0.777122
# 14480   1.148513 -1.312698           -0.745106     1.225246        0.537273
# ...          ...       ...                 ...          ...             ...
# 385    -1.367374  1.048903            1.658276    -0.618607       -0.719536
# 11924   1.078627 -0.787381            0.536698    -0.471916       -0.609205
# 13047  -0.863198  1.351076            0.536698     2.076147        1.777292
# 10331   0.888937 -0.838518           -1.866684     0.819060        0.424544
# 14428   1.148513 -1.321995            0.216247    -0.201280        0.220672
#
#        population  households  median_income ocean_proximity  \
# 11212   -0.360442   -0.603475      -0.821518       -0.021924
# 10317   -0.685546   -0.745354       4.148312       -0.021924
# 5086    -0.590350   -0.745354      -0.913400       -0.021924
# 7988     0.877110    0.870491       0.016069       -0.021924
# 14480    0.299646    0.589360       2.654206         2.04358
# ...           ...         ...            ...             ...
# 385     -0.775354   -0.695433      -0.212608        1.010828
# 11924   -0.645133   -0.561436       0.295372       -1.054676
# 13047    3.094466    2.026542      -0.620174       -1.054676
# 10331    0.425377    0.631398       1.965157       -0.021924
# 14428   -0.332601    0.258309      -0.440516         2.04358
#
#        rooms_per_household  bedrooms_per_room  population_per_household  \
# 11212            -0.014201           0.191714                  0.061195
# 10317             1.334104          -1.785296                  0.000289
# 5086             -0.635847           0.145201                  0.041896
# 7988             -0.480259           0.437442                 -0.017714
# 14480             0.874967          -1.230914                 -0.056753
# ...                    ...                ...                       ...
# 385               0.035831          -0.517495                 -0.057165
# 11924             0.098349          -0.656517                 -0.051074
# 13047             0.098766          -0.606578                  0.062060
# 10331             0.255587          -0.909643                 -0.045158
# 14428            -0.794907           1.300901                 -0.113045
#
#        median_house_value
# 11212            182900.0
# 10317            454300.0
# 5086              93000.0
# 7988             169800.0
# 14480            474000.0
# ...                   ...
# 385              276800.0
# 11924            120700.0
# 13047            112500.0
# 10331            266400.0
# 14428            212500.0
#
# [3922 rows x 13 columns]

# %%
test=test_set_without_target
test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11212   0.819052 -0.847816            0.056022    -0.543869       -0.508469
# 10317   0.863978 -0.838518           -0.264429    -0.384179       -0.803483
# 5086    0.634354 -0.773435            1.498051    -0.812648       -0.827468
# 7988    0.684272 -0.833869            0.777036     0.455117        0.777122
# 14480   1.148513 -1.312698           -0.745106     1.225246        0.537273
# ...          ...       ...                 ...          ...             ...
# 385    -1.367374  1.048903            1.658276    -0.618607       -0.719536
# 11924   1.078627 -0.787381            0.536698    -0.471916       -0.609205
# 13047  -0.863198  1.351076            0.536698     2.076147        1.777292
# 10331   0.888937 -0.838518           -1.866684     0.819060        0.424544
# 14428   1.148513 -1.321995            0.216247    -0.201280        0.220672
#
#        population  households  median_income ocean_proximity  \
# 11212   -0.360442   -0.603475      -0.821518       -0.021924
# 10317   -0.685546   -0.745354       4.148312       -0.021924
# 5086    -0.590350   -0.745354      -0.913400       -0.021924
# 7988     0.877110    0.870491       0.016069       -0.021924
# 14480    0.299646    0.589360       2.654206         2.04358
# ...           ...         ...            ...             ...
# 385     -0.775354   -0.695433      -0.212608        1.010828
# 11924   -0.645133   -0.561436       0.295372       -1.054676
# 13047    3.094466    2.026542      -0.620174       -1.054676
# 10331    0.425377    0.631398       1.965157       -0.021924
# 14428   -0.332601    0.258309      -0.440516         2.04358
#
#        rooms_per_household  bedrooms_per_room  population_per_household  \
# 11212            -0.014201           0.191714                  0.061195
# 10317             1.334104          -1.785296                  0.000289
# 5086             -0.635847           0.145201                  0.041896
# 7988             -0.480259           0.437442                 -0.017714
# 14480             0.874967          -1.230914                 -0.056753
# ...                    ...                ...                       ...
# 385               0.035831          -0.517495                 -0.057165
# 11924             0.098349          -0.656517                 -0.051074
# 13047             0.098766          -0.606578                  0.062060
# 10331             0.255587          -0.909643                 -0.045158
# 14428            -0.794907           1.300901                 -0.113045
#
#        median_house_value
# 11212            182900.0
# 10317            454300.0
# 5086              93000.0
# 7988             169800.0
# 14480            474000.0
# ...                   ...
# 385              276800.0
# 11924            120700.0
# 13047            112500.0
# 10331            266400.0
# 14428            212500.0
#
# [3922 rows x 13 columns]

# %% [markdown]
# ## Modeling

# %% [markdown]
# #### First, we will split between features and target value (labels) for train set:

# %%
housing = train.drop("median_house_value", axis=1)   #....> drop labels for training set
housing_labels = train["median_house_value"].copy()

housing
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2736    1.987142 -1.326644            1.738389    -0.614893       -0.625995
# 17659  -1.162709  0.760676            0.376473     0.155700       -0.021575
# 17654  -1.167700  0.746729           -0.584880    -0.248629       -0.446108
# 17544  -1.157717  0.788569            1.898615    -0.671063       -0.774701
# 8772    0.604403 -0.857113            0.376473    -0.195709       -0.165485
# ...          ...       ...                 ...          ...             ...
# 11575   0.774125 -0.871060           -0.024091    -0.099617       -0.083936
# 18228  -1.267537  0.821111           -0.825218    -0.529014       -0.155891
# 5425    0.564468 -0.754839            0.456585    -0.172963       -0.225447
# 12799  -0.948059  1.378969            0.296360    -0.083370        0.177499
# 236    -1.322447  0.997766            1.658276    -0.804756       -0.822671
#
#        population  households  median_income ocean_proximity  \
# 2736    -0.516708   -0.595592      -1.281953       -1.054676
# 17659   -0.135922    0.053373       0.314878       -0.021924
# 17654   -0.358646   -0.461596       1.042040       -0.021924
# 17544   -0.750208   -0.771628      -0.640321       -0.021924
# 8772    -0.406244   -0.272424       0.917820       -0.021924
# ...           ...         ...            ...             ...
# 11575   -0.255367   -0.117408      -0.096730       -0.021924
# 18228   -0.540058   -0.225131      -0.057526        1.010828
# 5425    -0.418817   -0.230385       0.836012       -0.021924
# 12799    0.062553    0.308229      -1.682525       -1.054676
# 236     -0.630763   -0.763745      -0.640321        1.010828
#
#        rooms_per_household  bedrooms_per_room  population_per_household
# 2736             -0.299836          -0.005576                  0.003533
# 17659             0.141273          -0.627446                 -0.054483
# 17654             0.482095          -0.804145                  0.007512
# 17544             0.135746          -0.548183                 -0.016519
# 8772              0.077517          -0.019626                 -0.053292
# ...                    ...                ...                       ...
# 11575            -0.043408          -0.094825                 -0.049310
# 18228            -0.834789           1.859945                 -0.093059
# 5425              0.033308          -0.298237                 -0.064384
# 12799            -0.656423           0.640393                 -0.057074
# 236              -0.536816           0.109388                  0.033876
#
# [15686 rows x 12 columns]

# %%
housing_labels
# Out:
# 2736      68100.0
# 17659    313100.0
# 17654    264500.0
# 17544    325900.0
# 8772     318900.0
#            ...
# 11575    211700.0
# 18228    274000.0
# 5425     414100.0
# 12799     81400.0
# 236      122000.0
# Name: median_house_value, Length: 15686, dtype: float64

# %% [markdown]
# #### Second, we will split between features and target value (labels) for test set

# %%
housing_t = test.drop("median_house_value", axis=1)   #....> drop labels for test set
housing_labels_t = test["median_house_value"].copy()

housing_t
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11212   0.819052 -0.847816            0.056022    -0.543869       -0.508469
# 10317   0.863978 -0.838518           -0.264429    -0.384179       -0.803483
# 5086    0.634354 -0.773435            1.498051    -0.812648       -0.827468
# 7988    0.684272 -0.833869            0.777036     0.455117        0.777122
# 14480   1.148513 -1.312698           -0.745106     1.225246        0.537273
# ...          ...       ...                 ...          ...             ...
# 385    -1.367374  1.048903            1.658276    -0.618607       -0.719536
# 11924   1.078627 -0.787381            0.536698    -0.471916       -0.609205
# 13047  -0.863198  1.351076            0.536698     2.076147        1.777292
# 10331   0.888937 -0.838518           -1.866684     0.819060        0.424544
# 14428   1.148513 -1.321995            0.216247    -0.201280        0.220672
#
#        population  households  median_income ocean_proximity  \
# 11212   -0.360442   -0.603475      -0.821518       -0.021924
# 10317   -0.685546   -0.745354       4.148312       -0.021924
# 5086    -0.590350   -0.745354      -0.913400       -0.021924
# 7988     0.877110    0.870491       0.016069       -0.021924
# 14480    0.299646    0.589360       2.654206         2.04358
# ...           ...         ...            ...             ...
# 385     -0.775354   -0.695433      -0.212608        1.010828
# 11924   -0.645133   -0.561436       0.295372       -1.054676
# 13047    3.094466    2.026542      -0.620174       -1.054676
# 10331    0.425377    0.631398       1.965157       -0.021924
# 14428   -0.332601    0.258309      -0.440516         2.04358
#
#        rooms_per_household  bedrooms_per_room  population_per_household
# 11212            -0.014201           0.191714                  0.061195
# 10317             1.334104          -1.785296                  0.000289
# 5086             -0.635847           0.145201                  0.041896
# 7988             -0.480259           0.437442                 -0.017714
# 14480             0.874967          -1.230914                 -0.056753
# ...                    ...                ...                       ...
# 385               0.035831          -0.517495                 -0.057165
# 11924             0.098349          -0.656517                 -0.051074
# 13047             0.098766          -0.606578                  0.062060
# 10331             0.255587          -0.909643                 -0.045158
# 14428            -0.794907           1.300901                 -0.113045
#
# [3922 rows x 12 columns]

# %%
housing_labels_t
# Out:
# 11212    182900.0
# 10317    454300.0
# 5086      93000.0
# 7988     169800.0
# 14480    474000.0
#            ...
# 385      276800.0
# 11924    120700.0
# 13047    112500.0
# 10331    266400.0
# 14428    212500.0
# Name: median_house_value, Length: 3922, dtype: float64

# %%
housing_t.isnull().sum()
# Out:
# longitude                   0
# latitude                    0
# housing_median_age          0
# total_rooms                 0
# total_bedrooms              0
# population                  0
# households                  0
# median_income               0
# ocean_proximity             0
# rooms_per_household         0
# bedrooms_per_room           0
# population_per_household    0
# dtype: int64

# %% [markdown]
# ## Creating a Decision tree regression model:

# %%
dtr = DecisionTreeRegressor()      # Create the model: Decision tree regression

# %%
# %%time
dtr.fit(housing, housing_labels)   # Fit to the Training set
# Out:
# CPU times: user 178 ms, sys: 2.91 ms, total: 181 ms
# Wall time: 180 ms
# DecisionTreeRegressor()

# %%
print("DTR model score Training Set:", dtr.score(housing, housing_labels))
print("DTR model score Testing Set:", dtr.score(housing_t, housing_labels_t))
cvs = cross_val_score(dtr, housing, housing_labels, scoring = "neg_mean_squared_error", cv=5)
cvs_sqrt = np.sqrt(-cvs)
cvs_mean = np.mean(cvs_sqrt) 
print("Cross validation score : ", cvs_mean)
# Out:
# DTR model score Training Set: 1.0
# DTR model score Testing Set: 0.5745431247488777
# Cross validation score :  62882.06264810198

# %%
prediction = dtr.predict(housing_t)  #....> Decision Tree Regression Model Evaluation (on Testing set)

# %%
print('MAE for Testing set:', mean_absolute_error(housing_labels_t, prediction))
print('MSE for Testing set:', mean_squared_error(housing_labels_t, prediction))
print('RMSE for Testing set:', np.sqrt(mean_squared_error(housing_labels_t, prediction)))
print("R^2 score for Testing set: ", r2_score(housing_labels_t, prediction))
# Out:
# MAE for Testing set: 41938.83248342682
# MSE for Testing set: 3978542699.5923
# RMSE for Testing set: 63075.69024269413
# R^2 score for Testing set:  0.5745431247488777

# %% [markdown]
# #### We got 100% score on Training set. On testing set we got almost 63% score because we didn't do any hyperparameters tuning. Due to which depth of tree increased and our model did the overfitting. To solve this problem  hyperparameter tuning will be utilized.
#
# #### We can use GridSearch or RandomizedSearch for hyper parameters tuning.

# %%
## Distribution plot between our label  and predicted values:
# checking difference between label and predicted label
sns.distplot(housing_labels_t-prediction)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Density'>

# %% [markdown]
# #### We can't get any conclusion about our model accrording the bell shape. Bell curve only tell us the range of predicted values are with in the same range as our original data range values are.

# %%
#...> checking predicted lables and our labeles using a scatter plot
plt.scatter(housing_labels_t, prediction)

# %% [markdown]
# ## <center> Hyper Parameter tuning

# %%
#....> Hyper parameters range intialization for tuning 
#....> Gridsearch to find the best parameters for our decision tree model.
dtr = DecisionTreeRegressor()      # Create the model: Decision tree regression for tuning    
params = {"criterion": ["squared_error", "absolute_error"],
              "min_samples_split": [10, 20, 40],
              "max_depth": [2, 6, 8],
              "min_samples_leaf": [20, 40, 100],
              "max_leaf_nodes": [5, 20, 100],
              }    
    
#....> calculating different regression metrics
tuning_dtr = GridSearchCV(dtr, param_grid=params, scoring='neg_mean_squared_error', cv=3, verbose=3, n_jobs=-1)

# %%
# %%time   
tuning_dtr.fit(housing, housing_labels)  #....> Fiting the tuned model on the traning set
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# CPU times: user 1.06 s, sys: 145 ms, total: 1.21 s
# Wall time: 2min 29s
# GridSearchCV(cv=3, estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error'],
#                          'max_depth': [2, 6, 8], 'max_leaf_nodes': [5, 20, 100],
#                          'min_samples_leaf': [20, 40, 100],
#                          'min_samples_split': [10, 20, 40]},
#              scoring='neg_mean_squared_error', verbose=3)

# %%
cvs_tuned = cross_val_score(tuning_dtr, housing, housing_labels, scoring = "neg_mean_squared_error", cv=5)
cvs_tuned_sqrt = np.sqrt(-cvs_tuned)
cvs_tuned_mean = np.mean(cvs_tuned_sqrt) 
print("-----------------------------------------------------------------------------------------------")
print("-----------------------------------------------------------------------------------------------")
print("Cross validation score after tuning : ", cvs_tuned_mean)
# Out:
# Fitting 3 folds for each of 162 candidates, totalling 486 fits
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5135116062.070 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5159205761.598 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5159205761.598 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5070485134.832 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-5135116062.070 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5070485134.832 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-5070485134.832 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4811871903.511 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4750322408.161 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3640755171.773 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3624973040.782 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4750322408.161 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4746522150.092 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4811871903.511 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4750322408.161 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4750322408.161 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3586040619.319 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3651692477.897 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3624973040.782 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3228792829.706 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3273111189.122 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3188419298.811 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3228792829.706 total time=   0.1s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5411531490.532 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-5412638974.240 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-5359075235.227 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-5411531490.532 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-5359075235.227 total time=   5.4s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-5411531490.532 total time=   5.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-5412638974.240 total time=   5.4s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-5359075235.227 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4978367825.650 total time=   8.0s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5124276291.050 total time=   7.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4928644894.818 total time=   7.8s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4978367825.650 total time=   7.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3473961022.395 total time=   8.2s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3446194120.788 total time=   8.0s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4928644894.818 total time=   7.4s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4928644894.818 total time=   7.6s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3678526667.929 total time=   8.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3833102079.920 total time=   8.1s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3833102079.920 total time=   8.0s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3412833937.942 total time=   8.4s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3427578169.937 total time=   6.8s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5080554271.709 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5080554271.709 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5110785813.980 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5080554271.709 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5110785813.980 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5080554271.709 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4626124462.420 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4774776027.218 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5135116062.070 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5070485134.832 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-5135116062.070 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5159205761.598 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-5070485134.832 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5070485134.832 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-5159205761.598 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-5135116062.070 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4746522150.092 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4811871903.511 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3640755171.773 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3624973040.782 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3610868017.895 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3640755171.773 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4746522150.092 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4811871903.511 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4750322408.161 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4746522150.092 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3067517465.463 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-2984140313.892 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3273111189.122 total time=   0.2s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3188419298.811 total time=   0.1s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5359075235.227 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5411531490.532 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5412638974.240 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5359075235.227 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-5412638974.240 total time=   5.5s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-5359075235.227 total time=   5.5s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-5411531490.532 total time=   5.4s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-5412638974.240 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4928644894.818 total time=   7.1s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4978367825.650 total time=   7.4s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5124276291.050 total time=   7.1s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4928644894.818 total time=   7.4s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3424421811.400 total time=   8.6s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3504844411.343 total time=   8.5s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4978367825.650 total time=   7.7s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4978367825.650 total time=   7.4s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4978367825.650 total time=   7.3s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3726997235.080 total time=   8.1s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3667330340.716 total time=   8.0s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3048980072.423 total time=   8.7s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3230731354.485 total time=   7.4s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5110785813.980 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4941222960.897 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-4941222960.897 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-5110785813.980 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-4941222960.897 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5110785813.980 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4626124462.420 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4774776027.218 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4766498539.794 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5070485134.832 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5070485134.832 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5135116062.070 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5135116062.070 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5135116062.070 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-5135116062.070 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5135116062.070 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-5070485134.832 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-5159205761.598 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4750322408.161 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4746522150.092 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3299287024.322 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3389425597.077 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3285757451.739 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3299287024.322 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3651692477.897 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3624973040.782 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3586040619.319 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3651692477.897 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3273111189.122 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3188419298.811 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3228792829.706 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5412638974.240 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-5412638974.240 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-5359075235.227 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-5411531490.532 total time=   5.4s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-5412638974.240 total time=   5.7s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5124276291.050 total time=   7.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4928644894.818 total time=   7.3s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4978367825.650 total time=   7.6s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5124276291.050 total time=   7.0s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3833102079.920 total time=   8.2s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3703596389.195 total time=   8.2s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3606290059.572 total time=   8.7s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3559624854.294 total time=   8.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5124276291.050 total time=   7.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5124276291.050 total time=   7.2s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4928644894.818 total time=   7.3s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3678526667.929 total time=   8.4s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3716070156.848 total time=   8.2s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3095231740.149 total time=   8.7s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3289400762.720 total time=   8.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4941222960.897 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4941222960.897 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-4941222960.897 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5110785813.980 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-5080554271.709 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-4941222960.897 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4774776027.218 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4766498539.794 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4626124462.420 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4774776027.218 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5135116062.070 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5135116062.070 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5070485134.832 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5070485134.832 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5070485134.832 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-5159205761.598 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-5135116062.070 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4811871903.511 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4750322408.161 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4811871903.511 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4750322408.161 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3282576197.756 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3299287024.322 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3389425597.077 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3282576197.756 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4811871903.511 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4750322408.161 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4746522150.092 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4811871903.511 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3105979240.248 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3067517465.463 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-2984140313.892 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3105979240.248 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5412638974.240 total time=   5.2s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5359075235.227 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5411531490.532 total time=   5.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5412638974.240 total time=   5.4s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5124276291.050 total time=   7.2s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4928644894.818 total time=   7.7s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4978367825.650 total time=   7.7s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5124276291.050 total time=   7.1s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3716130087.799 total time=   8.0s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3716070156.848 total time=   8.1s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3606290059.572 total time=   8.2s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3454458945.841 total time=   8.9s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3446194120.788 total time=   8.5s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4978367825.650 total time=   8.1s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4978367825.650 total time=   7.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3833102079.920 total time=   8.0s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3726997235.080 total time=   8.1s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3048980072.423 total time=   8.5s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3101845390.840 total time=   8.4s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3230731354.485 total time=   5.3s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5080554271.709 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5110785813.980 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-5080554271.709 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-4941222960.897 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5080554271.709 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-4941222960.897 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3537689334.323 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3622076788.605 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3617838106.411 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5135116062.070 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-5159205761.598 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5135116062.070 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-5135116062.070 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-5159205761.598 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-5135116062.070 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-5070485134.832 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4811871903.511 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4750322408.161 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3610868017.895 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3640755171.773 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3624867496.534 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3389425597.077 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4811871903.511 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4750322408.161 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4746522150.092 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4811871903.511 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3067817781.975 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-2910210821.978 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3093391501.642 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3070999035.957 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5412638974.240 total time=   5.1s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5359075235.227 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5411531490.532 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5412638974.240 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5412638974.240 total time=   5.7s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5359075235.227 total time=   5.8s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5411531490.532 total time=   5.7s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5412638974.240 total time=   5.8s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3716130087.799 total time=   8.5s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3833102079.920 total time=   8.5s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3716070156.848 total time=   8.5s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3606290059.572 total time=   9.0s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3603885537.675 total time=   9.0s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5124276291.050 total time=   7.7s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5124276291.050 total time=   7.4s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5124276291.050 total time=   7.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3833102079.920 total time=   8.4s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3833102079.920 total time=   8.2s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3399205253.203 total time=   8.9s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3427578169.937 total time=   8.2s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4941222960.897 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5110785813.980 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-5080554271.709 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-4941222960.897 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-4941222960.897 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-5110785813.980 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-5080554271.709 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4626124462.420 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4774776027.218 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4766498539.794 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3608063333.313 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5159205761.598 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5159205761.598 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5135116062.070 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5070485134.832 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-5070485134.832 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-5159205761.598 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-5070485134.832 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5135116062.070 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4746522150.092 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4811871903.511 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3624973040.782 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3586040619.319 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3282919378.008 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3336510260.183 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3361873496.457 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3282919378.008 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3586040619.319 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3651692477.897 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3624973040.782 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3610868017.895 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5412638974.240 total time=   5.2s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5359075235.227 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5411531490.532 total time=   5.4s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5412638974.240 total time=   5.4s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-5411531490.532 total time=   5.8s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5412638974.240 total time=   5.9s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5359075235.227 total time=   5.8s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5411531490.532 total time=   5.7s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3726997235.080 total time=   8.2s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3716130087.799 total time=   8.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3703596389.195 total time=   8.4s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3424421811.400 total time=   8.4s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3504844411.343 total time=   8.2s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3456270274.484 total time=   8.2s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4928644894.818 total time=   7.4s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4928644894.818 total time=   7.4s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3678526667.929 total time=   8.3s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3667330340.716 total time=   8.1s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3046407685.256 total time=   8.7s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3162098863.332 total time=   8.5s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5110785813.980 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4941222960.897 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4941222960.897 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5110785813.980 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-5080554271.709 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-4941222960.897 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-4941222960.897 total time=   0.0s
# ...
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3481684802.175 total time=   4.8s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5176448165.545 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5176448165.545 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-5176448165.545 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5160602799.045 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5160602799.045 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5212243692.910 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4662618825.155 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4813065729.123 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4858683448.811 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4662618825.155 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3455887663.492 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3387976014.650 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3404446742.614 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3514709397.117 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3709980709.721 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3577876896.943 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3609904560.765 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3709980709.721 total time=   0.1s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5453562981.210 total time=   3.9s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5387783505.427 total time=   3.9s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5349028016.376 total time=   4.0s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5453562981.210 total time=   3.9s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4889516001.076 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5080837628.592 total time=   5.0s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5097929790.988 total time=   4.9s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4889516001.076 total time=   4.9s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3823440861.224 total time=   5.5s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3846542125.198 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3495215045.422 total time=   5.6s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3608766009.300 total time=   5.4s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3573451467.177 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5097929790.988 total time=   4.7s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4889516001.076 total time=   4.8s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3806013274.492 total time=   5.4s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3806013274.492 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3282584935.406 total time=   5.7s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3305659981.115 total time=   5.6s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3476368678.533 total time=   3.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4967809800.164 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4967809800.164 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-5182915014.103 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-4967809800.164 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-5182915014.103 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-4967809800.164 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3547582573.210 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3664255931.271 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3436147706.216 total time=   4.9s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5160602799.045 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5160602799.045 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5176448165.545 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5160602799.045 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5176448165.545 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-5160602799.045 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4813065729.123 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4858683448.811 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4662618825.155 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4813065729.123 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3328587684.127 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3455887663.492 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3299238794.925 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3328587684.127 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3577876896.943 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3609904560.765 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3709980709.721 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3577876896.943 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5387783505.427 total time=   3.8s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5349028016.376 total time=   3.8s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5453562981.210 total time=   3.8s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5387783505.427 total time=   3.8s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-5453562981.210 total time=   3.8s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-5387783505.427 total time=   3.8s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-5349028016.376 total time=   3.8s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-5453562981.210 total time=   3.8s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3787857513.914 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3787857513.914 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3787857513.914 total time=   5.1s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3632413941.932 total time=   5.4s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3531519289.386 total time=   5.5s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3601026116.424 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4889516001.076 total time=   4.9s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5080837628.592 total time=   4.7s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3776078719.221 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3776078719.221 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3255404324.647 total time=   5.8s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3306583520.273 total time=   5.5s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3400684210.495 total time=   2.9s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5182915014.103 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5176024682.783 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5182915014.103 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-4967809800.164 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5176024682.783 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5182915014.103 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4575758662.429 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3118162343.626 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3373823060.806 total time=   0.1s
# -----------------------------------------------------------------------------------------------
# -----------------------------------------------------------------------------------------------
# Cross validation score after tuning :  54812.60731338395

# %%
tuning_dtr.best_params_
# Out:
# {'criterion': 'squared_error',
#  'max_depth': 8,
#  'max_leaf_nodes': 100,
#  'min_samples_leaf': 20,
#  'min_samples_split': 20}

# %%
tuning_dtr.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=8, max_leaf_nodes=100, min_samples_leaf=20,
#                       min_samples_split=20)

# %%
# %%time
tuned_pred = tuning_dtr.best_estimator_.predict(housing_t) #....> Applying it on the testing set (tuned version)
# Out:
# CPU times: user 4.46 ms, sys: 30 µs, total: 4.49 ms
# Wall time: 3.6 ms

# %%
#....> checking predicted lables (tuned version) and our labeles using a scatter plot
plt.scatter(housing_labels_t,tuned_pred)

# %%
print('MAE for Testing set(tuned):', mean_absolute_error(housing_labels_t,tuned_pred))
print('MSE for Testing set(tuned):', mean_squared_error(housing_labels_t, tuned_pred))
print('RMSE for Testing set(tuned):', np.sqrt(mean_squared_error(housing_labels_t, tuned_pred)))
print("R^2 score for Testing set(tuned): ", r2_score(housing_labels_t,tuned_pred))
# Out:
# MAE for Testing set(tuned): 38900.845859835325
# MSE for Testing set(tuned): 2942455677.2922716
# RMSE for Testing set(tuned): 54244.40687566112
# R^2 score for Testing set(tuned):  0.6853400622911546

# %%
#....> Finiding feature importances
features    = housing_t.columns
importances = tuning_dtr.best_estimator_.feature_importances_
combined    = pd.Series(importances, features)
combined
# Out:
# longitude                   0.037974
# latitude                    0.035107
# housing_median_age          0.023618
# total_rooms                 0.003517
# total_bedrooms              0.002498
# population                  0.000000
# households                  0.000000
# median_income               0.542211
# ocean_proximity             0.225042
# rooms_per_household         0.003273
# bedrooms_per_room           0.006732
# population_per_household    0.120028
# dtype: float64

# %%
#....> Ploting feature importances
from matplotlib.pyplot import figure
figure()
combined.sort_values().plot.barh(color="b")
plt.title("Feature importance")
plt.xlabel("Importance")
plt.ylabel("Features")
plt.show()

# %%
#....> Ploting the results
test = pd.DataFrame({'Predicted':tuned_pred,'Actual':housing_labels_t})
fig = plt.figure(figsize=(16,8))
test = test.reset_index()
test = test.drop(['index'],axis=1)
plt.plot(test[:50])
plt.legend(['Actual','Predicted'])
sns.jointplot(x='Actual',y='Predicted',data=test,kind="reg")
# Out:
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4761303763.838 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3574952930.386 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3673554106.264 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3368088317.670 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3290663318.707 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4761303763.838 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3063481075.142 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3125569380.785 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-2930285005.037 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3063481075.142 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5395431071.576 total time=   3.7s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5321813440.809 total time=   3.7s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4925183617.021 total time=   4.7s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4884027313.627 total time=   4.7s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5086256448.913 total time=   4.6s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4925183617.021 total time=   4.7s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3833923810.065 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3644015402.750 total time=   5.0s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3457355771.743 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3428901777.432 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3622510279.106 total time=   5.0s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4925183617.021 total time=   4.7s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4884027313.627 total time=   4.6s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3604225501.961 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3604225501.961 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3291189605.714 total time=   5.5s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3138508125.747 total time=   5.4s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5182915014.103 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-4967809800.164 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4575758662.429 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3361067834.557 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3065927110.633 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3290663318.707 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3361067834.557 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4817287199.904 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3125569380.785 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-2930285005.037 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3279306396.427 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3275677536.256 total time=   0.1s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5381237323.093 total time=   3.7s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5321813440.809 total time=   3.7s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5395431071.576 total time=   3.7s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5381237323.093 total time=   3.7s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4884027313.627 total time=   4.8s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5086256448.913 total time=   4.6s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4925183617.021 total time=   4.7s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4884027313.627 total time=   4.7s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3604225501.961 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3809757032.226 total time=   5.1s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3411497783.290 total time=   5.4s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3479432773.321 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3540436984.772 total time=   5.1s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5086256448.913 total time=   4.5s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5086256448.913 total time=   4.4s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3809757032.226 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3809757032.226 total time=   5.0s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3101816706.862 total time=   5.5s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3208712782.883 total time=   5.4s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3787857513.914 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3787857513.914 total time=   5.0s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3242230454.005 total time=   5.6s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3268170371.743 total time=   5.7s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5176024682.783 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5176024682.783 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-5182915014.103 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-4967809800.164 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-4967809800.164 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-5176024682.783 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3547582573.210 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3664255931.271 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3547582573.210 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3373823060.806 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3471824601.920 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3181160776.139 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3373823060.806 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3368088317.670 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3574952930.386 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3676808714.489 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3368088317.670 total time=   0.1s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5321813440.809 total time=   3.8s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5381237323.093 total time=   3.7s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5321813440.809 total time=   3.5s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-5321813440.809 total time=   3.8s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5381237323.093 total time=   3.8s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5321813440.809 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3833923810.065 total time=   5.1s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3833923810.065 total time=   5.1s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3644015402.750 total time=   5.1s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3411497783.290 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3370649407.961 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3424484259.455 total time=   5.0s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5086256448.913 total time=   4.5s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5086256448.913 total time=   4.4s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3798850426.727 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3644015402.750 total time=   5.0s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3101816706.862 total time=   5.5s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3083913550.921 total time=   5.4s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3065927110.633 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3290663318.707 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3361067834.557 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3065927110.633 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3648056578.525 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3580808171.669 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3648056578.525 total time=   0.1s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5395431071.576 total time=   3.7s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5381237323.093 total time=   3.7s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5321813440.809 total time=   3.7s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-5395431071.576 total time=   3.7s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-5321813440.809 total time=   3.7s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-5395431071.576 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3604225501.961 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3809757032.226 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3833923810.065 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3604225501.961 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3479432773.321 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5086256448.913 total time=   4.5s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4925183617.021 total time=   4.7s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4884027313.627 total time=   4.6s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3809757032.226 total time=   5.2s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3809757032.226 total time=   5.0s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3291189605.714 total time=   5.5s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3357502630.839 total time=   5.2s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5176024682.783 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-5182915014.103 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-4967809800.164 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-4967809800.164 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-5176024682.783 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-5176024682.783 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-5182915014.103 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-4967809800.164 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-5176024682.783 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3547582573.210 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3664255931.271 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3547582573.210 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4817287199.904 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3096713624.084 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-2879816104.991 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3097821987.843 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3096713624.084 total time=   0.1s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5321813440.809 total time=   3.5s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-5321813440.809 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4884027313.627 total time=   4.6s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5086256448.913 total time=   4.4s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4925183617.021 total time=   4.5s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4884027313.627 total time=   4.5s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3411497783.290 total time=   5.2s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3622510279.106 total time=   4.9s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5086256448.913 total time=   4.4s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5086256448.913 total time=   4.4s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4884027313.627 total time=   4.5s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3604225501.961 total time=   5.0s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3644015402.750 total time=   4.9s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3101816706.862 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3305797606.933 total time=   4.8s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-5182915014.103 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3664255931.271 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3574952930.386 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3673554106.264 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4761303763.838 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3097821987.843 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3096713624.084 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-2880118231.253 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3097821987.843 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5395431071.576 total time=   3.5s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-5321813440.809 total time=   3.5s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5395431071.576 total time=   3.7s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5381237323.093 total time=   3.7s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5395431071.576 total time=   3.7s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3833923810.065 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3604225501.961 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3809757032.226 total time=   5.2s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3833923810.065 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3428901777.432 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4925183617.021 total time=   4.7s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4925183617.021 total time=   4.7s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4925183617.021 total time=   4.6s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3798850426.727 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3829167822.735 total time=   5.1s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3163127880.110 total time=   5.6s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3403136442.744 total time=   5.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3471824601.920 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3181160776.139 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3580808171.669 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3648056578.525 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3580808171.669 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3279306396.427 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3275677536.256 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3111985573.831 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5395431071.576 total time=   3.7s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-5395431071.576 total time=   3.5s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-5381237323.093 total time=   3.5s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-5395431071.576 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5086256448.913 total time=   4.4s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4925183617.021 total time=   4.6s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4884027313.627 total time=   4.6s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5086256448.913 total time=   4.4s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3809757032.226 total time=   5.0s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3898864488.405 total time=   5.1s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3397965692.924 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3370649407.961 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4884027313.627 total time=   4.6s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4884027313.627 total time=   4.6s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3809757032.226 total time=   5.1s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3809757032.226 total time=   5.1s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3809757032.226 total time=   4.9s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3208712782.883 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3357502630.839 total time=   4.6s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-4967809800.164 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4817287199.904 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3265070791.160 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3388879563.729 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3118162343.626 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3258959075.438 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3580808171.669 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3648056578.525 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3394838243.314 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3111985573.831 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3279306396.427 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3275677536.256 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3111985573.831 total time=   0.1s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5086256448.913 total time=   4.5s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4925183617.021 total time=   4.7s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4884027313.627 total time=   4.7s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5086256448.913 total time=   4.5s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3809757032.226 total time=   5.1s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3898864488.405 total time=   5.0s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3644015402.750 total time=   4.9s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3479432773.321 total time=   5.1s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3540436984.772 total time=   4.9s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-5086256448.913 total time=   4.4s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5086256448.913 total time=   4.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3809757032.226 total time=   5.1s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3604225501.961 total time=   5.1s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3644015402.750 total time=   4.9s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3083913550.921 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3305797606.933 total time=   4.0s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4575758662.429 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3368088317.670 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3574952930.386 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3673554106.264 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3368088317.670 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4575758662.429 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-2880118231.253 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3069592790.865 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3125569380.785 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-2930285005.037 total time=   0.1s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-5321813440.809 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-5381237323.093 total time=   3.5s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-5321813440.809 total time=   3.5s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-5086256448.913 total time=   4.4s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4925183617.021 total time=   4.5s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=40;, score=-4884027313.627 total time=   4.5s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3809757032.226 total time=   5.1s
# ...
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-5182915014.103 total time=   0.0s
# [CV 3/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-4967809800.164 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-5176024682.783 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3388879563.729 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3118162343.626 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3258959075.438 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=40;, score=-3388879563.729 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3580808171.669 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3648056578.525 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=20;, score=-3394838243.314 total time=   0.1s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-5321813440.809 total time=   3.7s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-5381237323.093 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-5381237323.093 total time=   3.5s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-5395431071.576 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-5381237323.093 total time=   3.5s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4925183617.021 total time=   4.5s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4884027313.627 total time=   4.7s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-5086256448.913 total time=   4.4s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4925183617.021 total time=   4.4s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-3457355771.743 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-3540436984.772 total time=   5.1s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4925183617.021 total time=   4.8s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-4925183617.021 total time=   4.8s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=10;, score=-3798850426.727 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3809757032.226 total time=   5.3s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3291189605.714 total time=   5.6s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3208712782.883 total time=   5.5s
# [CV 1/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3357502630.839 total time=   3.7s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5176024682.783 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-5182915014.103 total time=   0.0s
# [CV 1/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5176024682.783 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-5182915014.103 total time=   0.0s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3664255931.271 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3547582573.210 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3664255931.271 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4817287199.904 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=20;, score=-4575758662.429 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3580808171.669 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3648056578.525 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3394838243.314 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3574952930.386 total time=   0.1s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5395431071.576 total time=   3.7s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-5321813440.809 total time=   3.7s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5395431071.576 total time=   3.7s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5381237323.093 total time=   3.7s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=40;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-5395431071.576 total time=   3.7s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-5381237323.093 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3809757032.226 total time=   5.0s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3809757032.226 total time=   5.0s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3898864488.405 total time=   4.9s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3397965692.924 total time=   5.2s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=10;, score=-3370649407.961 total time=   5.1s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-3424484259.455 total time=   4.9s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=40;, score=-4884027313.627 total time=   4.6s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=10;, score=-4925183617.021 total time=   4.4s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=20;, score=-3798850426.727 total time=   5.1s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3798850426.727 total time=   5.0s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=10;, score=-3163127880.110 total time=   5.3s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3138508125.747 total time=   5.2s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3403136442.744 total time=   3.3s
# [CV 2/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3471824601.920 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3181160776.139 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4761303763.838 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=20, min_samples_split=10;, score=-4817287199.904 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3676808714.489 total time=   0.1s
# [CV 3/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3368088317.670 total time=   0.1s
# [CV 1/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3574952930.386 total time=   0.1s
# [CV 2/3] END criterion=squared_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=20;, score=-3676808714.489 total time=   0.1s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5381237323.093 total time=   3.7s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=20;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5395431071.576 total time=   3.7s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=40;, score=-5381237323.093 total time=   3.6s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-5381237323.093 total time=   3.7s
# [CV 3/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=10;, score=-5321813440.809 total time=   3.6s
# [CV 1/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-5395431071.576 total time=   3.8s
# [CV 2/3] END criterion=absolute_error, max_depth=2, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=20;, score=-5381237323.093 total time=   3.6s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=10;, score=-3604225501.961 total time=   5.1s
# [CV 3/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=40, min_samples_split=40;, score=-3604225501.961 total time=   5.1s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=40;, score=-3809757032.226 total time=   4.9s
# [CV 1/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3457355771.743 total time=   5.2s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3428901777.432 total time=   5.2s
# [CV 2/3] END criterion=absolute_error, max_depth=6, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3622510279.106 total time=   5.0s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=40, min_samples_split=10;, score=-4884027313.627 total time=   4.6s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=5, min_samples_leaf=100, min_samples_split=20;, score=-4925183617.021 total time=   4.5s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=20, min_samples_split=40;, score=-3604225501.961 total time=   5.1s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=20, min_samples_leaf=100, min_samples_split=10;, score=-3829167822.735 total time=   4.9s
# [CV 2/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=20, min_samples_split=20;, score=-3163127880.110 total time=   5.4s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=40, min_samples_split=20;, score=-3083913550.921 total time=   5.3s
# [CV 3/3] END criterion=absolute_error, max_depth=8, max_leaf_nodes=100, min_samples_leaf=100, min_samples_split=40;, score=-3305797606.933 total time=   3.0s
